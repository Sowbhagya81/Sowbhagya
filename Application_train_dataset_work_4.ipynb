# %%
import pandas as pd

# %%
df=pd.read_csv('/content/application_train.csv')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Calculate Credit to Income Ratio
df['CREDIT_INCOME_RATIO'] = df['AMT_CREDIT'] / df['AMT_INCOME_TOTAL']

# Step 2: Group by education level and calculate average ratio
edu_credit_ratio = df.groupby('NAME_EDUCATION_TYPE')['CREDIT_INCOME_RATIO'].mean().reset_index()

# Step 3: Plot the bar graph
plt.figure(figsize=(10, 6))
sns.barplot(data=edu_credit_ratio, x='NAME_EDUCATION_TYPE', y='CREDIT_INCOME_RATIO', palette='viridis')
plt.title('Average Credit to Income Ratio by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Average Credit to Income Ratio')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-5-3004697839.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=edu_credit_ratio, x='NAME_EDUCATION_TYPE', y='CREDIT_INCOME_RATIO', palette='viridis')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Create pivot table for average AMT_CREDIT
pivot_table = df.pivot_table(
    index='NAME_FAMILY_STATUS',
    columns='NAME_INCOME_TYPE',
    values='AMT_CREDIT',
    aggfunc='mean'
)
pivot_table
# Out:
# NAME_INCOME_TYPE       Businessman  Commercial associate  Maternity leave  \
# NAME_FAMILY_STATUS
# Civil marriage        9.000000e+05         608338.671828              NaN
# Married               1.227857e+06         711909.539537         749700.0
# Separated                      NaN         626815.552237              NaN
# Single / not married  1.395000e+06         572727.338686              NaN
# Unknown                        NaN         630000.000000              NaN
# Widow                          NaN         639130.852294              NaN
#
# NAME_INCOME_TYPE          Pensioner  State servant    Student  Unemployed  \
# NAME_FAMILY_STATUS
# Civil marriage        509791.925217  586975.984259  441141.75    747000.0
# Married               595688.655624  707510.346480  539061.00    843750.0
# Separated             488403.686158  614547.089273  450000.00   1080000.0
# Single / not married  472907.530699  565482.690485  532014.75    686700.0
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Create pivot table for average AMT_CREDIT
pivot_table = df.pivot_table(
    index='NAME_FAMILY_STATUS',
    columns='NAME_INCOME_TYPE',
    values='AMT_CREDIT',
    aggfunc='mean'
)

# Step 2: Plot the heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap='YlGnBu')
plt.title('Average Loan Amount by Family Status and Income Type')
plt.xlabel('Income Type')
plt.ylabel('Family Status')
plt.tight_layout()
plt.show()
